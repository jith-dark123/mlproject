# %% [markdown]
# <a href="https://colab.research.google.com/github/jith-dark123/mlproject/blob/main/Pandas_1_Practice_Mckinsey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd #pd is an alias name
import numpy as np

# %%
https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
# Out:
#   File "/tmp/ipython-input-1183269077.py", line 1
#     https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
#                                       ^
# SyntaxError: invalid decimal literal

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 113MB/s]

# %%
df = pd.read_csv('mckinsey.csv') #storing the data in df
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head() #prints the top 5 rows by default
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(8)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %%
df.head(15)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.tail() #print the bottom 5 rows by default
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
#find the no. of rows and columns
df.shape
# Out:
# (1704, 6)

# %%
df.head?

# %%
df.head(-5)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1694     Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695     Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696     Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697     Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698     Zimbabwe  1982     7636524    Africa    60.363  788.855041
#
# [1699 rows x 6 columns]

# %%
#basics operations on columns
#add a column
#delete a column
#rename a column

# %%
#df.columns
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() #using the method keys() of dataframe
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head() #access a singlre column
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
#access multiple columns
df[['country','life_exp']].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
df.head?

# %%
#how can we find the countries that have been surveyed ?
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
len(df['country'].unique())
# Out:
# 142

# %%
df['country'].nunique()
# Out:
# 142

# %%
#check the count of occurences of each country
df['country'].value_counts()
# Out:
# country
# Afghanistan           12
# Albania               12
# Algeria               12
# Angola                12
# Argentina             12
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen, Rep.           12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %%
#change the name of a column
df.rename(columns = {'population':'Population','country':'Country'})
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#change the name of a column
df.rename({'population':'Population','country':'Country'},axis = 1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({'population':'Population','country':'Country'},axis = 1,inplace=True)
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#shares_memory

# %%
df['Country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: Country, Length: 1704, dtype: object

# %%
df.Country #alternative of getting column values
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: Country, Length: 1704, dtype: object

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent',axis=1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop(columns = ['continent'])
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent',axis=1,inplace=True)

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
#create a new column
df['year+7'] = df['year'] + 7
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979

# %%
df['gdp'] = df['gdp_cap'] * df['Population']
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09

# %%
df['Own'] = [i for i in range(1704)]
df
# Out:
#           Country  year  Population  life_exp     gdp_cap  year+7  \
# 0     Afghanistan  1952     8425333    28.801  779.445314    1959
# 1     Afghanistan  1957     9240934    30.332  820.853030    1964
# 2     Afghanistan  1962    10267083    31.997  853.100710    1969
# 3     Afghanistan  1967    11537966    34.020  836.197138    1974
# 4     Afghanistan  1972    13079460    36.088  739.981106    1979
# ...           ...   ...         ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    2014
#
#                gdp   Own
# 0     6.567086e+09     0
# 1     7.585449e+09     1
# 2     8.758856e+09     2
# 3     9.648014e+09     3
# 4     9.678553e+09     4
# ...

# %%
df.drop(columns = ['Own','gdp','year+7'],inplace=True)
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
#Given a dataframe consisting of 5 columns, which is the correct code to drop the 3rd column from the start?

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
#basics operations => change the row index
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index = list(range(1,df.shape[0]+1))
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333    28.801  779.445314
# 2     Afghanistan  1957     9240934    30.332  820.853030
# 3     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1967    11537966    34.020  836.197138
# 5     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.shape
# Out:
# (1704, 5)

# %%
df.shape[0]
# Out:
# 1704

# %%
df.shape[1]
# Out:
# 5

# %%
#explicit and implicit indices

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333    28.801  779.445314
# 2     Afghanistan  1957     9240934    30.332  820.853030
# 3     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1967    11537966    34.020  836.197138
# 5     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.index[1] #implicit index 1 , explicit index 2
# Out:
# np.int64(2)

# %%
df.index= np.arange(1,df.shape[0]+1,dtype = 'float')
df
# Out:
#             Country  year  Population  life_exp     gdp_cap
# 1.0     Afghanistan  1952     8425333    28.801  779.445314
# 2.0     Afghanistan  1957     9240934    30.332  820.853030
# 3.0     Afghanistan  1962    10267083    31.997  853.100710
# 4.0     Afghanistan  1967    11537966    34.020  836.197138
# 5.0     Afghanistan  1972    13079460    36.088  739.981106
# ...             ...   ...         ...       ...         ...
# 1700.0     Zimbabwe  1987     9216418    62.351  706.157306
# 1701.0     Zimbabwe  1992    10704340    60.377  693.420786
# 1702.0     Zimbabwe  1997    11404948    46.809  792.449960
# 1703.0     Zimbabwe  2002    11926563    39.989  672.038623
# 1704.0     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
sample = df.head()
sample
# Out:
#          Country  year  Population  life_exp     gdp_cap
# 1.0  Afghanistan  1952     8425333    28.801  779.445314
# 2.0  Afghanistan  1957     9240934    30.332  820.853030
# 3.0  Afghanistan  1962    10267083    31.997  853.100710
# 4.0  Afghanistan  1967    11537966    34.020  836.197138
# 5.0  Afghanistan  1972    13079460    36.088  739.981106

# %%
#string indices
sample.index = ['a','b','c','d','e']
sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# a  Afghanistan  1952     8425333    28.801  779.445314
# b  Afghanistan  1957     9240934    30.332  820.853030
# c  Afghanistan  1962    10267083    31.997  853.100710
# d  Afghanistan  1967    11537966    34.020  836.197138
# e  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.index = np.arange(1,df.shape[0]+1,dtype='int')
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333    28.801  779.445314
# 2     Afghanistan  1957     9240934    30.332  820.853030
# 3     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1967    11537966    34.020  836.197138
# 5     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
#access any particular row with index on a series
ser = df['Country']
ser
# Out:
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
#            ...
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# 1704       Zimbabwe
# Name: Country, Length: 1704, dtype: object

# %%
ser.head(20)
# Out:
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# Name: Country, dtype: object

# %%
ser[2] #series => indexing => explicit indexing
# Out:
# 'Afghanistan'

# %%
ser[13]
# Out:
# 'Albania'

# %%
ser[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-1430aae6f4a5> in <cell line: 0>()
# ----> 1 ser[0]
#
# ...

# %%
#slicing
ser.head(20)
# Out:
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# Name: Country, dtype: object

# %%
ser[6:16] #implicit indexing => avoid this confusion => standard way => loc and iloc => next class
# Out:
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# Name: Country, dtype: object

# %%
ser[-15:-20:-1] #implict
# Out:
# 1690    Zambia
# 1689    Zambia
# 1688    Zambia
# 1687    Zambia
# 1686    Zambia
# Name: Country, dtype: object

# %%
#doubts
arr = np.array([[[0, 1],
             [2, 3]],

            [[4, 5],
             [6, 7]]])
arr
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
arr[:, 0:,:1]
# Out:
# array([[[0],
#         [2]],
#
#        [[4],
#         [6]]])
